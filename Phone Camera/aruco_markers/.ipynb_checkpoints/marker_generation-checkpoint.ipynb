# %% [markdown]
# # Amazon Webscraping

# %%
from bs4 import BeautifulSoup
import requests

# %%
request = requests.get("https://www.amazon.com/dp/1400096235")
soup = BeautifulSoup(request.text, features='html.parser')

# %%
soup.find_all("a")
# Out:
# [<a onclick="window.location.reload()">Try different image</a>,
#  <a href="https://www.amazon.com/gp/help/customer/display.html/ref=footer_cou?ie=UTF8&amp;nodeId=508088">Conditions of Use</a>,
#  <a href="https://www.amazon.com/gp/help/customer/display.html/ref=footer_privacy?ie=UTF8&amp;nodeId=468496">Privacy Policy</a>]

# %% [markdown]
# # Aruco Board Printing

# %%
import numpy as np
import cv2, PIL
from cv2 import aruco
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
# %matplotlib nbagg

# %%
aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_50)

nx = 3
ny = 3
marker_size_cm = 0.5
marker_size_inches = marker_size_cm * 2.54
padding=marker_size_cm

# fig = plt.figure(figsize=(marker_size_inches * nx, marker_size_inches * ny))

for offset in range(0, 50, 9):
    if offset + 9 < 50:
        fig = plt.figure(figsize=(marker_size_inches * nx, marker_size_inches * ny))
        for i in range(1, nx*ny+1):
            ax = fig.add_subplot(ny, nx, i)
            img = aruco.drawMarker(aruco_dict, i+offset, 800)
            plt.imshow(img, cmap = mpl.cm.gray, interpolation = "nearest")
            ax.axis("off")
            ax.annotate(i+offset, xy=(0.5, 1.05), 
                        ha='left', va='bottom', size=5, 
                        xycoords='axes fraction')
        plt.subplots_adjust(wspace=padding, 
                            hspace=padding)

        plt.savefig(f"markers_{nx}x{ny}_{offset+1}.pdf")
        plt.show()
# Out:
# <img src="data:image/png;base64,..." width="381">
# <img src="data:image/png;base64,..." width="381">
# <img src="data:image/png;base64,..." width="381">
# <img src="data:image/png;base64,..." width="381">
# <img src="data:image/png;base64,..." width="381">
