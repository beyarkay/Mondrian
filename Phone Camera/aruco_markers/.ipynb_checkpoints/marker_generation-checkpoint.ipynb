# %% [markdown]
# # Aruco Board Printing

# %%
import numpy as np
import cv2, PIL
from cv2 import aruco
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
import glob
# %matplotlib nbagg

# %%
aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_50)
dict_size = 50
nx = 5
ny = 5
marker_size_cm = 10
marker_size_inches = marker_size_cm * 2.54
padding = marker_size_cm/2


for offset in range(0, dict_size, nx*ny):
    if offset + nx*ny <= dict_size:
        fig = plt.figure(figsize=(nx*marker_size_cm/5, ny*marker_size_cm/5))
        for i in range(0, nx*ny):
            ax = fig.add_subplot(ny, nx, i+1)
            img = aruco.drawMarker(aruco_dict, i + offset, marker_size_cm*100)
            plt.imshow(img, cmap = mpl.cm.gray, interpolation = "nearest")
            ax.axis("off")
            ax.annotate(i+offset, xy=(0.5, 1.05), 
                        ha='left', va='bottom', size=10, 
                        xycoords='axes fraction')
        plt.subplots_adjust(wspace=0.25, 
                            hspace=0.25)

        plt.savefig(f"markers_{nx}x{ny}_{offset}.png")
        plt.show()

# %% [markdown]
# # Aruco Board generation, but without id labels

# %%
board = aruco.GridBoard_create(nx, ny, marker_size_inches, padding, aruco_dict)

imboard = board.draw((500, 500))
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
plt.imshow(imboard, cmap = mpl.cm.gray, interpolation = "nearest")
ax.axis("off")
plt.savefig(f"gridboard_{nx}x{ny}_{offset}.png")
plt.show()

# %% [markdown]
# # Charuco Calibration
# from https://mecaruco2.readthedocs.io/en/latest/notebooks_rst/Aruco/sandbox/ludovic/aruco_calibration_rotation.html

# %%
workdir = "./"
aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_250)
num_x, num_y = 7, 7
ratio_marker_border = 6/8
board = aruco.CharucoBoard_create(num_x, num_y, 1, ratio_marker_border, aruco_dict)
imboard = board.draw((2000, 2000))
cv2.imwrite(f"{workdir}charuco_{num_x}x{num_y}.tiff", imboard)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
plt.imshow(imboard, cmap = mpl.cm.gray, interpolation = "nearest")
ax.axis("off")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Get the calibration photos

# %%
datadir = "calibration_photos/"
images = np.array([datadir + f for f in os.listdir(datadir) if f.endswith(".jpg")])
order = np.argsort([int(p.split(".")[-2].split("_")[-1]) for p in images])
images = images[order]
images
# Out:
# array(['calibration_photos/img_0.jpg', 'calibration_photos/img_1.jpg',
#        'calibration_photos/img_2.jpg', 'calibration_photos/img_3.jpg',
#        'calibration_photos/img_4.jpg', 'calibration_photos/img_5.jpg',
#        'calibration_photos/img_6.jpg', 'calibration_photos/img_7.jpg',
#        'calibration_photos/img_8.jpg', 'calibration_photos/img_9.jpg',
#        'calibration_photos/img_10.jpg', 'calibration_photos/img_11.jpg',
#        'calibration_photos/img_12.jpg', 'calibration_photos/img_13.jpg',
#        'calibration_photos/img_14.jpg', 'calibration_photos/img_15.jpg',
#        'calibration_photos/img_16.jpg', 'calibration_photos/img_17.jpg',
#        'calibration_photos/img_18.jpg', 'calibration_photos/img_19.jpg',
#        'calibration_photos/img_20.jpg', 'calibration_photos/img_21.jpg',
#        'calibration_photos/img_22.jpg', 'calibration_photos/img_23.jpg',
#        'calibration_photos/img_24.jpg', 'calibration_photos/img_25.jpg',
# ...

# %%
im = PIL.Image.open(images[0])
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
plt.imshow(im)
ax.axis('off')
plt.show()
image = cv2.imread(images[0])
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
imsize = gray.shape
print(imsize)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (2304, 4608)

# %%
def read_chessboards(images):
    """
    Charuco base pose estimation.
    """
    print("POSE ESTIMATION STARTS:")
    allCorners = []
    allIds = []
    decimator = 0
    # SUB PIXEL CORNER DETECTION CRITERION
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.00001)

    for im in images:
        print(f"=> Processing image {im}")
        frame = cv2.imread(im)
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        corners, ids, rejectedImgPoints = cv2.aruco.detectMarkers(gray, aruco_dict)

        if len(corners) > 0:
            # SUB PIXEL DETECTION
            for corner in corners:
                cv2.cornerSubPix(gray, corner,
                                 winSize = (3,3),
                                 zeroZone = (-1,-1),
                                 criteria = criteria)
            res2 = cv2.aruco.interpolateCornersCharuco(corners,ids,gray,board)
            if res2[1] is not None and res2[2] is not None and len(res2[1])>3 and decimator%1==0:
                allCorners.append(res2[1])
                allIds.append(res2[2])

        decimator+=1

    imsize = gray.shape
    return allCorners,allIds,imsize

# %%
allCorners, allIds, imsize = read_chessboards(images)
# Out:
# POSE ESTIMATION STARTS:
# => Processing image calibration_photos/img_0.jpg
# => Processing image calibration_photos/img_1.jpg
# => Processing image calibration_photos/img_2.jpg
# => Processing image calibration_photos/img_3.jpg
# => Processing image calibration_photos/img_4.jpg
# => Processing image calibration_photos/img_5.jpg
# => Processing image calibration_photos/img_6.jpg
# => Processing image calibration_photos/img_7.jpg
# => Processing image calibration_photos/img_8.jpg
# => Processing image calibration_photos/img_9.jpg
# => Processing image calibration_photos/img_10.jpg
# => Processing image calibration_photos/img_11.jpg
# => Processing image calibration_photos/img_12.jpg
# => Processing image calibration_photos/img_13.jpg
# => Processing image calibration_photos/img_14.jpg
# => Processing image calibration_photos/img_15.jpg
# => Processing image calibration_photos/img_16.jpg
# => Processing image calibration_photos/img_17.jpg
# ...

# %%
def calibrate_camera(allCorners, allIds, imsize):
    """
    Calibrates the camera using the dected corners.
    """
    print("CAMERA CALIBRATION")

    cameraMatrixInit = np.array([[ 1000.,    0., imsize[0]/2.],
                                 [    0., 1000., imsize[1]/2.],
                                 [    0.,    0.,           1.]])

    distCoeffsInit = np.zeros((5,1))
    flags = (cv2.CALIB_USE_INTRINSIC_GUESS + cv2.CALIB_RATIONAL_MODEL + cv2.CALIB_FIX_ASPECT_RATIO)
    (ret, camera_matrix, distortion_coeffs0,
     r_vecs, t_vecs,
     stdDeviationsIntrinsics, stdDeviationsExtrinsics,
     perViewErrors) = cv2.aruco.calibrateCameraCharucoExtended(
                      charucoCorners=allCorners,
                      charucoIds=allIds,
                      board=board,
                      imageSize=imsize,
                      cameraMatrix=cameraMatrixInit,
                      distCoeffs=distCoeffsInit,
                      flags=flags,
                      criteria=(cv2.TERM_CRITERIA_EPS & cv2.TERM_CRITERIA_COUNT, 10000, 1e-9))
    print(f"Per View Errors: {perViewErrors}")
    return ret, camera_matrix, distortion_coeffs0, r_vecs, t_vecs

# %%
# %time ret, camera_matrix, distortion_coeffs0, r_vecs, t_vecs = calibrate_camera(allCorners, allIds, imsize)
# Out:
# CAMERA CALIBRATION
# Per View Errors: [[ 20.63391397]
#  [  8.42861904]
#  [ 17.41523345]
#  [ 37.73828047]
#  [ 89.32869296]
#  [114.08213055]
#  [ 21.44540533]
#  [ 25.17842533]
#  [ 17.71092239]
#  [  8.98068684]
#  [ 16.8076936 ]
#  [ 13.03426582]
#  [ 40.07612667]
#  [ 67.16760931]
#  [ 33.20080392]
#  [ 35.68748185]
#  [ 30.85342545]
#  [ 18.97224292]
#  [ 39.16517961]
#  [ 39.04194659]
#  [ 32.68452183]
#  [ 38.38054182]
#  [ 36.24708809]
#  [ 40.16608899]
#  [ 45.06782885]
#  [ 54.66002992]
#  [ 76.34283848]
#  [ 13.99200809]
#  [ 13.5250286 ]
#  [ 20.42344616]
#  [ 21.54710604]
#  [ 18.86445933]
#  [ 17.2975513 ]
#  [ 18.24387345]
#  [ 26.33852142]
#  [ 28.28543135]
#  [ 62.63986717]
#  [ 19.32495434]]
# CPU times: user 12.1 s, sys: 118 ms, total: 12.2 s
# Wall time: 12.4 s

# %%
distortion_coeffs0
# Out:
# array([[ 0.03047091],
#        [-0.00273724],
#        [ 0.05033091],
#        [ 0.01688091],
#        [ 0.00153252],
#        [-0.01895321],
#        [ 0.00889097],
#        [ 0.000518  ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])

# %%
camera_matrix
# Out:
# array([[ 1.37622593e+03,  0.00000000e+00, -5.78296238e+02],
#        [ 0.00000000e+00,  1.37622593e+03,  1.55199148e+03],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]])

# %%
ret
# Out:
# 40.26329607747963

# %%
# i=27 # select image id
i=11
plt.figure(figsize=(7, 4))
frame = cv2.imread(images[i])
img_undist = cv2.undistort(frame, camera_matrix, distortion_coeffs0, None)
plt.subplot(1,2,1)
plt.imshow(frame)
plt.title("Raw image")
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(img_undist)
plt.title("Corrected image")
plt.axis("off")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
print("Starting")
total = 0
datadir = "calibration_photos/"
# images = np.array([datadir + f for f in os.listdir(datadir) if f.endswith(".jpg")])

for i, file_path in enumerate(glob.glob(datadir + "*")):
#     file_path = f"calibration_photos/img_{i}.jpg"
    frame = cv2.imread(file_path)
    # plt.figure()
    # plt.imshow(frame, interpolation = "nearest")
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_250)
    parameters =  aruco.DetectorParameters_create()
    corners, ids, rejectedImgPoints = aruco.detectMarkers(gray, aruco_dict,
                                                          parameters=parameters)
    # SUB PIXEL DETECTION
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.0001)
    for corner in corners:
        cv2.cornerSubPix(gray, corner, winSize = (3,3), zeroZone = (-1,-1), criteria=criteria)

    frame_markers = aruco.drawDetectedMarkers(frame.copy(), corners, ids)
    accuracy = 100*len(corners)/((num_x*num_y)//2)
    print(f"{file_path}: {round(accuracy, 2)}", end="")
    if accuracy < 100:
        print(f"\tremoving")
        os.remove(file_path)
    else:
        print("")
    total += accuracy
print(f"total accuracy = {total / len(glob.glob(datadir + '*'))}" )
# plt.figure()
# plt.imshow(frame_markers, interpolation = "nearest")

# plt.show()
# Out:
# Starting
# calibration_photos/img_10.jpg: 100.0
# calibration_photos/img_1.jpg: 100.0
# calibration_photos/img_0.jpg: 100.0
# calibration_photos/img_11.jpg: 100.0
# calibration_photos/img_13.jpg: 100.0
# calibration_photos/img_2.jpg: 100.0
# calibration_photos/img_3.jpg: 100.0
# calibration_photos/img_12.jpg: 100.0
# calibration_photos/img_16.jpg: 100.0
# calibration_photos/img_7.jpg: 100.0
# calibration_photos/img_6.jpg: 100.0
# calibration_photos/img_17.jpg: 100.0
# calibration_photos/img_29.jpg: 100.0
# calibration_photos/img_15.jpg: 100.0
# calibration_photos/img_4.jpg: 104.17
# calibration_photos/img_5.jpg: 100.0
# calibration_photos/img_14.jpg: 100.0
# calibration_photos/img_28.jpg: 100.0
# calibration_photos/img_31.jpg: 100.0
# calibration_photos/img_25.jpg: 100.0
# calibration_photos/img_19.jpg: 100.0
# calibration_photos/img_8.jpg: 100.0
# calibration_photos/img_9.jpg: 100.0
# calibration_photos/img_18.jpg: 104.17
# calibration_photos/img_24.jpg: 100.0
# ...

# %%
size_of_marker =  0.0285 # side length of the marker in meter
rvecs, tvecs, objPoints = aruco.estimatePoseSingleMarkers(
    corners, 
    size_of_marker, 
    camera_matrix, 
    distortion_coeffs0)

length_of_axis = 0.1
imaxis = aruco.drawDetectedMarkers(frame.copy(), corners, ids)

for i in range(len(tvecs)):
    imaxis = aruco.drawAxis(imaxis, camera_matrix, distortion_coeffs0, rvecs[i], tvecs[i], length_of_axis)
    
plt.figure()
plt.imshow(imaxis)
# plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
